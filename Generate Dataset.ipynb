# %%
import os
  
# Directory
directory = "Face Dataset"
  
# Path
path = os.path.join(directory)

try:
    os.mkdir(path)
except:
    pass

# %%
import cv2
import glob
import os
import shutil

actual_count = 0

for person in range(1, 750):
    name = "00"+ str(person)
    # The name of the file starts with this name
    name = name[-3:]
    
    src_dir = os.path.join("Neutral_Front")
    
    if os.path.exists(os.path.join(src_dir, name + "_03.jpg")):
        actual_count += 1
        
        # Making a new Directory
        dst_dir = os.path.join("Dataset","Face Dataset")
        
        # Adding the actual image
        try:
            os.mkdir(os.path.join(dst_dir, str(actual_count)))
        except:
            pass
        
        
        # Copy Neutral Face image to the dataset
        try:
            shutil.copy(os.path.join(src_dir, name + "_03.jpg"), os.path.join(os.path.join(dst_dir, str(actual_count)), str(actual_count) + ".jpg"))
        except Error as err:
                errors.extend(err.args[0])
        
        
    
    # Copy Smiling Image to the dataset (Indexed _1)
    src_smile_dir = os.path.join("Smiling_Front")
    
    if os.path.exists(os.path.join(src_smile_dir, name + "_08.jpg")):
        dst_pose_dir = os.path.join("Dataset","Face Dataset", str(actual_count))
        
        try:
            os.mkdir(os.path.join(dst_pose_dir, "Pose"))
        except:
            pass
        
        try:
            os.mkdir(os.path.join(dst_pose_dir, "Filtered"))
        except:
            pass
        
        dst_pose_dir = os.path.join(dst_pose_dir, "Pose")
        
        try:
            shutil.copy(os.path.join(src_smile_dir, name + "_08.jpg"), os.path.join(dst_pose_dir, str(actual_count) + "_1.jpg"))
        except Error as err:
                errors.extend(err.args[0])
                
                
    # Copy 3/4 Left Profile (Indexed _2)
    src_semi_left_dir = os.path.join("Semi_Left")
    
    if os.path.exists(os.path.join(src_semi_left_dir, name + "_02.jpg")):
        dst_pose_dir = os.path.join("Dataset","Face Dataset", str(actual_count))
        
        try:
            os.mkdir(os.path.join(dst_pose_dir, "Pose"))
        except:
            pass
        
        dst_pose_dir = os.path.join(dst_pose_dir, "Pose")
        
        try:
            shutil.copy(os.path.join(src_semi_left_dir, name + "_02.jpg"), os.path.join(dst_pose_dir, str(actual_count) + "_2.jpg"))
        except Error as err:
                errors.extend(err.args[0])
                
                
    # Copy Left Profile (Indexed _3)
    src_left_dir = os.path.join("Left")
    
    if os.path.exists(os.path.join(src_left_dir, name + "_01.jpg")):
        dst_pose_dir = os.path.join("Dataset","Face Dataset", str(actual_count))
        
        try:
            os.mkdir(os.path.join(dst_pose_dir, "Pose"))
        except:
            pass
        
        dst_pose_dir = os.path.join(dst_pose_dir, "Pose")
        
        try:
            shutil.copy(os.path.join(src_left_dir, name + "_01.jpg"), os.path.join(dst_pose_dir, str(actual_count) + "_3.jpg"))
        except Error as err:
                errors.extend(err.args[0])
                
    
    # Copy Semi Right Profile (Indexed _4)
    src_semi_right_dir = os.path.join("Semi_Right")
    
    if os.path.exists(os.path.join(src_semi_right_dir, name + "_04.jpg")):
        dst_pose_dir = os.path.join("Dataset","Face Dataset", str(actual_count))
        
        try:
            os.mkdir(os.path.join(dst_pose_dir, "Pose"))
        except:
            pass
        
        dst_pose_dir = os.path.join(dst_pose_dir, "Pose")
        
        try:
            shutil.copy(os.path.join(src_semi_right_dir, name + "_04.jpg"), os.path.join(dst_pose_dir, str(actual_count) + "_4.jpg"))
        except Error as err:
                errors.extend(err.args[0])
                
                
                
    # Copy Right Profile (Indexed _5)
    src_right_dir = os.path.join("Right")
    
    if os.path.exists(os.path.join(src_right_dir, name + "_05.jpg")):
        dst_pose_dir = os.path.join("Dataset","Face Dataset", str(actual_count))
        
        try:
            os.mkdir(os.path.join(dst_pose_dir, "Pose"))
        except:
            pass
        
        dst_pose_dir = os.path.join(dst_pose_dir, "Pose")
        
        try:
            shutil.copy(os.path.join(src_right_dir, name + "_05.jpg"), os.path.join(dst_pose_dir, str(actual_count) + "_5.jpg"))
        except Error as err:
                errors.extend(err.args[0])
                
    # Copy Smiling Semi Left Profile (Indexed _6)
    src_smiling_semi_left_dir = os.path.join("Smiling_Semi_Left")
    
    if os.path.exists(os.path.join(src_smiling_semi_left_dir, name + "_07.jpg")):
        dst_pose_dir = os.path.join("Dataset","Face Dataset", str(actual_count))
        
        try:
            os.mkdir(os.path.join(dst_pose_dir, "Pose"))
        except:
            pass
        
        dst_pose_dir = os.path.join(dst_pose_dir, "Pose")
        
        try:
            shutil.copy(os.path.join(src_smiling_semi_left_dir, name + "_07.jpg"), os.path.join(dst_pose_dir, str(actual_count) + "_6.jpg"))
        except Error as err:
                errors.extend(err.args[0])
                
    
    # Copy Smiling Left Profile (Indexed _7)
    src_smiling_left_dir = os.path.join("Smiling_Left")
    
    if os.path.exists(os.path.join(src_smiling_left_dir, name + "_06.jpg")):
        dst_pose_dir = os.path.join("Dataset","Face Dataset", str(actual_count))
        
        try:
            os.mkdir(os.path.join(dst_pose_dir, "Pose"))
        except:
            pass
        
        dst_pose_dir = os.path.join(dst_pose_dir, "Pose")
        
        try:
            shutil.copy(os.path.join(src_smiling_left_dir, name + "_06.jpg"), os.path.join(dst_pose_dir, str(actual_count) + "_7.jpg"))
        except Error as err:
                errors.extend(err.args[0])
                
    
    # Copy Smiling Semi Right Profile (Indexed _8)
    src_smiling_semi_right_dir = os.path.join("Smiling_Semi_Right")
    
    if os.path.exists(os.path.join(src_smiling_semi_right_dir, name + "_09.jpg")):
        dst_pose_dir = os.path.join("Dataset","Face Dataset", str(actual_count))
        
        try:
            os.mkdir(os.path.join(dst_pose_dir, "Pose"))
        except:
            pass
        
        dst_pose_dir = os.path.join(dst_pose_dir, "Pose")
        
        try:
            shutil.copy(os.path.join(src_smiling_semi_right_dir, name + "_09.jpg"), os.path.join(dst_pose_dir, str(actual_count) + "_8.jpg"))
        except Error as err:
                errors.extend(err.args[0])
                
                
    # Copy Smiling Right Profile (Indexed _9)
    src_smiling_right_dir = os.path.join("Smiling_Right")
    
    if os.path.exists(os.path.join(src_smiling_right_dir, name + "_10.jpg")):
        dst_pose_dir = os.path.join("Dataset","Face Dataset", str(actual_count))
        
        try:
            os.mkdir(os.path.join(dst_pose_dir, "Pose"))
        except:
            pass
        
        dst_pose_dir = os.path.join(dst_pose_dir, "Pose")
        
        try:
            shutil.copy(os.path.join(src_smiling_right_dir, name + "_10.jpg"), os.path.join(dst_pose_dir, str(actual_count) + "_9.jpg"))
        except Error as err:
                errors.extend(err.args[0])
